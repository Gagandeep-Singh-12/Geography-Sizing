# %%
import linkedin_scraper
from pyvirtualdisplay import Display
display = Display(visible=0, size=(1920, 1080))  
display.start()
# Out:
# /usr/lib/python3/dist-packages/requests/__init__.py:89: RequestsDependencyWarning: urllib3 (1.26.8) or chardet (3.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "

# %%
Linkedin_obj = linkedin_scraper.format_LinkedIn()

# %%
Linkedin_obj.LinkedIn_func('/home/celebal/Data/cookies/cookies_activity.pkl', '1mage Software, Inc.', 'https://1mage.com/')
# Out:
# company : 1mage Software, Inc.  & company_website : https://1mage.com/
# https://www.linkedin.com/feed/
# https://www.linkedin.com/company/1mage-software

# %%
display.stop()

# %%
import pickle
pickle.load(open('/home/celebal/Pipeline/outputs/context_output.pkl','rb'))
# Out:
# [{'Country': {'ca': 50.0, 'id': 16.666666666666664, 'cn': 33.33333333333333},
#   'State': {'ca': {'toronto': 50.0}}},
#  {'Country': {'de': 4.0358744394618835,
#    'in': 1.7937219730941705,
#    'ca': 2.690582959641256,
#    'sg': 1.7937219730941705,
#    'cn': 2.690582959641256,
#    'fr': 3.587443946188341,
#    'gb': 4.484304932735426,
#    'nl': 1.7937219730941705,
#    'us': 77.13004484304933},
#   'State': {'sg': {'singapore': 1.7937219730941705},
#    'nl': {'leiden': 1.7937219730941705},
#    'us': {'CA': 77.13004484304933}}},
#  {'Country': {'us': 100.0}, 'State': {'us': {'CO': 100.0}}},
#  {'Country': {'fr': 18.181818181818183,
#    'gb': 39.39393939393939,
#    'us': 18.181818181818183,
#    'au': 24.242424242424242},
#   'State': {'fr': {'arcueil': 18.181818181818183},
#    'gb': {'leinster': 39.39393939393939},
#    'us': {'VA': 18.181818181818183},
#    'au': {'cambridge': 16.16161616161616, 'cronulla': 8.08080808080808}}},
#  {'Country': {'in': 1.4285714285714286,
# ...
