# %%
import linkedin_scraper
from pyvirtualdisplay import Display
display = Display(visible=0, size=(1920, 1080))  
display.start()
# Out:
# /usr/lib/python3/dist-packages/requests/__init__.py:89: RequestsDependencyWarning: urllib3 (1.26.8) or chardet (3.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "

# %%
Linkedin_obj = linkedin_scraper.format_LinkedIn()

# %%
Linkedin_obj.LinkedIn_func('/home/celebal/Data/cookies/cookies_activity.pkl', '01 Communique Laboratory Inc.', 'https://www.01com.com/')
# Out:
# company : 01 Communique Laboratory Inc.  & company_website : https://www.01com.com/
# https://www.linkedin.com/feed/
# https://www.linkedin.com/company/01-communique
# /home/celebal/Pipeline/linkedin_scraper.py:206: GuessedAtParserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 206 of the file /home/celebal/Pipeline/linkedin_scraper.py. To get rid of this warning, pass the additional argument 'features="lxml"' to the BeautifulSoup constructor.
#
#   linkedin_soup = BeautifulSoup(about_source.encode("utf-8"), "html")
# Website Checking : http://www.01com.com & https://www.01com.com/
# web1 : 01com.com & web2 : 01com.com
# {'company_name': '01 Communique Laboratory Inc.',
# ...

# %%
display.stop()

# %%
import config
lc = config.Local_config()
cookie_folder = lc.cookie_folder

# %%
'{}/updated_cookies_activity.pkl'.format(lc.cookie_folder)
# Out:
# '/home/celebal/Data/cookies/updated_cookies_activity.pkl'
