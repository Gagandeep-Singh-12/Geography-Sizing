# %%
import config
import Heuristic_model

# %%
lc = config.Local_config()
obj1 = Heuristic_model.Model(lc.CENSUS_AGE_PATH,lc.CENSUS_INCOME_PATH,lc.CENSUS_POP_PATH)

# %%
import pymongo

uri = "mongodb://celebal:bZPUhXkQDcdWioAIiwECCdSEiZL3zmQ6bojzYjdiDxQlHhBgzKrJjiuYCWtEbSB4QcinajhByNwKbWlsRoBQ0A==@celebal.mongo.cosmos.azure.com:10255/?ssl=true&replicaSet=globaldb&retrywrites=false&maxIdleTimeMS=120000&appName=@celebal@"
client = pymongo.MongoClient(uri)
mongo_data1 = client.get_database(name="geography_sizing").get_collection(name='company_data')
mongo_data1
# Out:
# /usr/lib/python3/dist-packages/requests/__init__.py:89: RequestsDependencyWarning: urllib3 (1.26.8) or chardet (3.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "
# Collection(Database(MongoClient(host=['celebal.mongo.cosmos.azure.com:10255'], document_class=dict, tz_aware=False, connect=True, replicaset='globaldb', retrywrites=False, maxidletimems=120000, appname='@celebal@', tls=True), 'geography_sizing'), 'company_data')

# %%
import pickle
outputs = []
cursor = mongo_data1.find({})
c=0
assumed_revenue = 100
for document in cursor:
    res = {}
    res['_id'] = document['_id']
    if 'error' in document['Linkedin'].keys():
        res['error'] = 'company not found on linkedin'
    elif 'sales_data' == None:
        res['error'] = 'Sales data not available'
    #elif :

    else:
        c += 1
        Country_Dist,State_Dist = obj1.Distribute(document['Linkedin']['sales_data'], document['Linkedin']['locations_data'], document['Glassdoor'],document['Website'],assumed_revenue)
        #res['Country_Dist'] = Country_Dist
        #res['State_Dist'] = State_Dist
        #pickle.dump(res, open('outputs/Result.pkl', 'wb'))
        #print(document['_id'])
        print(Country_Dist)
        print("\n\n\n",State_Dist)
        if c > 1:
            break
# Out:
# {'id': 16.666666666666664, 'cn': 33.33333333333333, 'ca': 50.0}
#
#
#
#  {'ca': {'Toronto': 50.0}}
# {'us': 76.81818181818181, 'cn': 2.727272727272727, 'ca': 2.727272727272727, 'in': 1.8181818181818181, 'nl': 1.8181818181818181, 'gb': 4.090909090909091, 'sg': 1.8181818181818181, 'fr': 3.6363636363636362, 'de': 4.545454545454546}
#
#
#
#  {'us': {'CA': 76.81818181818181}, 'nl': {'Leiden': 1.8181818181818181}, 'sg': {'Singapore': 1.8181818181818181}}

# %%
cookie_path = '/home/celebal/Data/cookies/cookies_celebal.pkl'

# %%
import linkedin_scraper
# Out:
# /usr/lib/python3/dist-packages/requests/__init__.py:89: RequestsDependencyWarning: urllib3 (1.26.8) or chardet (3.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "

# %%
obj = linkedin_scraper.format_LinkedIn()
obj.LinkedIn_func(cookie_path, 'Alteryx, Inc.','https://www.alteryx.com/')
# Out:
# company : Alteryx, Inc.  & company_website : https://www.alteryx.com/
# https://www.linkedin.com/feed/
# https://www.linkedin.com/company/alteryx
# /home/celebal/Pipeline/linkedin_scraper.py:186: GuessedAtParserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 186 of the file /home/celebal/Pipeline/linkedin_scraper.py. To get rid of this warning, pass the additional argument 'features="lxml"' to the BeautifulSoup constructor.
#
#   linkedin_soup = BeautifulSoup(about_source.encode("utf-8"), "html")
# Website Checking : http://www.alteryx.com & https://www.alteryx.com/
# web1 : alteryx.com & web2 : alteryx.com
# {'company_name': 'Alteryx, Inc.',
#  'company_website': 'https://www.alteryx.com/',
#  'sales_data': {'country': ['us',
#    'gb',
#    'us',
#    'us',
#    'us',
#    'gb',
#    'de',
#    'us',
#    'sg',
#    'ca',
#    'us',
#    'fr',
#    'us',
#    'au',
#    'fr'],
#   'sales_count': ['479',
#    '99',
#    '88',
#    '59',
#    '55',
#    '52',
#    '38',
#    '31',
#    '30',
#    '29',
#    '24',
#    '22',
#    '21',
#    '19',
#    '18']},
#  'locations_data': {'us': ['CA', 'CO', 'CA', 'IL', 'NY', 'TX', 'TX'],
#   'gb': ['London'],
#   'fr': ['Paris'],
#   'cz': ['Prague'],
#   'jp': ['Tokyo'],
#   'de': ['Munich'],
#   'ca': ['Toronto'],
#   'sg': ['Singapore'],
#   'ua': ['Kyiv'],
#   'au': ['Sydney  '],
#   'ae': ['Internet City']},
#  'timestamp': datetime.datetime(2022, 3, 28, 19, 49, 5, 98882)}

# %%
import context
import pandas as pd
import pickle
l=[]
df = pd.read_csv("/home/celebal/Data/companies_data.csv")
for i in range(2950,3001):
    company = df.iloc[i, 3]
    website = df.iloc[i, 0]
    obj = context.context(company,website,100)
    l.append(obj.Ditribute())
    pickle.dump(l , open("test.pkl","wb"))
# Out:
# company : Sera Prognostics, Inc.  & company_website : https://seraprognostics.com/
# https://www.linkedin.com/
# https://www.linkedin.com/company/sera-prognostics
# https://www.linkedin.com/company/sera-prognostics?trk=ppro_cprof
# https://www.linkedin.com/company/sera-prognostics
# https://www.linkedin.com/company/sera-prognostics
# ##########AUTHWALL#############################
# https://seraprognostics.com/
# https://seraprognostics.com/
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '/']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '/']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '/']
# https://seraprognostics.com/
# openURL
# 7
# {'https://seraprognostics.com/about/newsroom/sera-prognostics-to-present-at-upcoming-march-investor-conferences/', 'https://seraprognostics.com/about/leadership/', 'https://seraprognostics.com/about/', 'https://seraprognostics.com/about/newsroom/', 'https://seraprognostics.com/about/newsroom/sera-prognostics-presents-data-demonstrating-prediction-of-preeclampsia-utilizing-protein-biomarker-and-clinical-factors-at-sri-annual-meeting/', 'https://seraprognostics.com/about/newsroom/sera-prognostics-reports-fourth-quarter-2021-financial-results/', 'https://seraprognostics.com/contact-us/'}
# links_website
# https://seraprognostics.com/about/newsroom/sera-prognostics-to-present-at-upcoming-march-investor-conferences/
# https://seraprognostics.com/about/newsroom/sera-prognostics-to-present-at-upcoming-march-investor-conferences/
# https://seraprognostics.com/about/newsroom/sera-prognostics-to-present-at-upcoming-march-investor-conferences/
# openURL
# https://seraprognostics.com/about/newsroom/sera-prognostics-to-present-at-upcoming-march-investor-conferences/
# https://seraprognostics.com/about/leadership/
# https://seraprognostics.com/about/leadership/
# https://seraprognostics.com/about/leadership/
# openURL
# https://seraprognostics.com/about/leadership/
# https://seraprognostics.com/about/
# https://seraprognostics.com/about/
# https://seraprognostics.com/about/
# openURL
# https://seraprognostics.com/about/
# https://seraprognostics.com/about/newsroom/
# https://seraprognostics.com/about/newsroom/
# https://seraprognostics.com/about/newsroom/
# openURL
# https://seraprognostics.com/about/newsroom/
# https://seraprognostics.com/about/newsroom/sera-prognostics-presents-data-demonstrating-prediction-of-preeclampsia-utilizing-protein-biomarker-and-clinical-factors-at-sri-annual-meeting/
# https://seraprognostics.com/about/newsroom/sera-prognostics-presents-data-demonstrating-prediction-of-preeclampsia-utilizing-protein-biomarker-and-clinical-factors-at-sri-annual-meeting/
# https://seraprognostics.com/about/newsroom/sera-prognostics-presents-data-demonstrating-prediction-of-preeclampsia-utilizing-protein-biomarker-and-clinical-factors-at-sri-annual-meeting/
# openURL
# https://seraprognostics.com/about/newsroom/sera-prognostics-presents-data-demonstrating-prediction-of-preeclampsia-utilizing-protein-biomarker-and-clinical-factors-at-sri-annual-meeting/
# https://seraprognostics.com/
# https://seraprognostics.com/
# https://seraprognostics.com/
# openURL
# https://seraprognostics.com/
# https://seraprognostics.com/about/newsroom/sera-prognostics-reports-fourth-quarter-2021-financial-results/
# https://seraprognostics.com/about/newsroom/sera-prognostics-reports-fourth-quarter-2021-financial-results/
# https://seraprognostics.com/about/newsroom/sera-prognostics-reports-fourth-quarter-2021-financial-results/
# openURL
# https://seraprognostics.com/about/newsroom/sera-prognostics-reports-fourth-quarter-2021-financial-results/
# https://seraprognostics.com/contact-us/
# https://seraprognostics.com/contact-us/
# https://seraprognostics.com/contact-us/
# openURL
# https://seraprognostics.com/contact-us/
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /home/celebal/Pipeline/Test.ipynb Cell 8' in <cell line: 6>()
#       <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a2232302e3130362e3135352e3139222c2275736572223a2263656c6562616c227d/home/celebal/Pipeline/Test.ipynb#ch0000007vscode-remote?line=7'>8</a> website = df.iloc[i, 0]
#       <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a2232302e3130362e3135352e3139222c2275736572223a2263656c6562616c227d/home/celebal/Pipeline/Test.ipynb#ch0000007vscode-remote?line=8'>9</a> obj = context.context(company,website,100)
# ---> <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a2232302e3130362e3135352e3139222c2275736572223a2263656c6562616c227d/home/celebal/Pipeline/Test.ipynb#ch0000007vscode-remote?line=9'>10</a> l.append(obj.Ditribute())
#      <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a2232302e3130362e3135352e3139222c2275736572223a2263656c6562616c227d/home/celebal/Pipeline/Test.ipynb#ch0000007vscode-remote?line=10'>11</a> pickle.dump(l , open("test.pkl","wb"))
#
# File ~/Pipeline/context.py:79, in context.Ditribute(self)
#      <a href='file:///home/celebal/Pipeline/context.py?line=76'>77</a> def Ditribute(self):
#      <a href='file:///home/celebal/Pipeline/context.py?line=77'>78</a>     self.check()
# ---> <a href='file:///home/celebal/Pipeline/context.py?line=78'>79</a>     return self.Model.Distribute(self.Data['Linkedin']['sales_data'], self.Data['Linkedin']['locations_data'], self.Data['Glassdoor'],self.Data['Website'],self.Revenue)
#
# KeyError: 'sales_data'
