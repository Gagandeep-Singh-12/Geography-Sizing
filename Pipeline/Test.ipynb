# %%
import config
import Heuristic_model

# %%
lc = config.Local_config()
obj1 = Heuristic_model.Model(lc.CENSUS_AGE_PATH,lc.CENSUS_INCOME_PATH,lc.CENSUS_POP_PATH)

# %%
import pymongo

uri = "mongodb://celebal:bZPUhXkQDcdWioAIiwECCdSEiZL3zmQ6bojzYjdiDxQlHhBgzKrJjiuYCWtEbSB4QcinajhByNwKbWlsRoBQ0A==@celebal.mongo.cosmos.azure.com:10255/?ssl=true&replicaSet=globaldb&retrywrites=false&maxIdleTimeMS=120000&appName=@celebal@"
client = pymongo.MongoClient(uri)
mongo_data1 = client.get_database(name="geography_sizing").get_collection(name='company_data')
mongo_data1

# %%
cursor = mongo_data1.find({})
for document in cursor:
    mongo_data1.delete_one(document)

# %%
import pickle
outputs = []
cursor = mongo_data1.find({})
c=0
assumed_revenue = 100
for document in cursor:
    res = {}
    res['_id'] = document['_id']
    if 'error' in document['Linkedin'].keys():
        res['error'] = 'company not found on linkedin'
    elif 'sales_data' == None:
        res['error'] = 'Sales data not available'
    #elif :

    else:
        c += 1
        Country_Dist,State_Dist = obj1.Distribute(document['Linkedin']['sales_data'], document['Linkedin']['locations_data'], document['Glassdoor'],document['Website'],assumed_revenue)
        #res['Country_Dist'] = Country_Dist
        #res['State_Dist'] = State_Dist
        #pickle.dump(res, open('outputs/Result.pkl', 'wb'))
        #print(document['_id'])
        print(Country_Dist)
        print("\n\n\n",State_Dist)
        if c > 1:
            break

# %%
cookie_path = '/home/celebal/Data/cookies/cookies_celebal.pkl'

# %%
import linkedin_scraper

# %%
obj = linkedin_scraper.format_LinkedIn()
obj.LinkedIn_func(cookie_path, 'Alteryx, Inc.','https://www.alteryx.com/')

# %%
import context
import pandas as pd
import pickle
l=[]
#df = pd.read_csv("/home/celebal/Data/companies_data.csv")
#for i in range(2950,3001):
#    company = df.iloc[i, 3]
#    website = df.iloc[i, 0]
obj = context.context("Alteryx, Inc.","https://www.alteryx.com/",100)
l.append(obj.Ditribute())
#    pickle.dump(l , open("test.pkl","wb"))

# %%
df = pd.read_csv("/home/celebal/Data/companies_data.csv")
df.head()
# Out:
#                         website                   timestamp  \
# 0        https://www.01com.com/  2022-02-01 11:01:35.964066
# 1  https://www.10xgenomics.com/  2022-02-01 11:02:06.390629
# 2            https://1mage.com/  2022-02-01 11:02:39.488454
# 3         https://1spatial.com/  2022-02-01 11:03:04.018106
# 4      https://www.23andme.com/  2022-02-01 11:03:32.107857
#
#                                 industry                   company_name  \
# 0                      Computer Software  01 Communique Laboratory Inc.
# 1                          Biotechnology             10x Genomics, Inc.
# 2                      Computer Software           1mage Software, Inc.
# 3  Information Technology &amp; Services                   1Spatial Plc
# 4                          Biotechnology            23andMe Holding Co.
#
#                                             about_us            headquarters  \
# 0  01 Communique is an innovation leader in the z...                     NaN
# 1  Accelerating biological understanding and disc...  Pleasanton, California
# 2  1mage Software Inc (“one image”) has designed ...          Centennial, CO
# 3  We are global leaders in managing geospatial d...                     NaN
# 4  23andMe, headquartered in Sunnyvale, CA, is a ...   Sunnyvale, California
#
#   employee_range  employee_profile  year-founded  locations  \
# 0         Nov-50                51        1992.0        NaN
# 1    1,001-5,000              1694        2012.0        NaN
# 2         Nov-50                 9        1980.0        NaN
# 3        201-500               186        1969.0        6.0
# 4      501-1,000               726        2006.0        NaN
#
#                                          specialties  \
# 0  Remote access software\nonline meeting softwar...
# 1                                                NaN
# 2  Document Imaging\nPaperless Office\nTechnical ...
# 3  Location-based information management\ndata qu...
# 4  genetic research\nconsumer genetics\nand direc...
#
#                                         what_they_do  capitaliq_employee
# 0                                                NaN                  11
# 1  {'Research': '383', 'Engineering': '199', 'Sal...                1148
# 2  {'Sales': '3', 'Business Development': '3', 'A...                  13
# 3                                                NaN                 286
# 4                                                NaN                 500

# %%
from pyvirtualdisplay import Display
display = Display(visible=0, size=(1920, 1080))  
display.start()

# %%
obj = context.context("10x Genomics, Inc.","https://www.10xgenomics.com/",100)
obj.Ditribute()
# Out:
# {'Country': {'gb': 4.484304932735426,
#   'us': 77.13004484304933,
#   'cn': 2.690582959641256,
#   'ca': 2.690582959641256,
#   'in': 1.7937219730941705,
#   'fr': 3.587443946188341,
#   'sg': 1.7937219730941705,
#   'nl': 1.7937219730941705,
#   'de': 4.0358744394618835},
#  'State': {'us': {'CA': 77.13004484304933},
#   'sg': {'singapore': 1.7937219730941705},
#   'nl': {'leiden': 1.7937219730941705}}}

# %%
display.stop()
